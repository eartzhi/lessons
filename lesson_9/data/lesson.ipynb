# %%
import pandas as pd

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc['US'])
# Out:
# США

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Out:
# Казахстан

# %%
print(countries.iloc[1:4])
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
pd.Series(["Апельсин", "Киви", "Мандарин", "Яблоко"], name='fruits')
# Out:
# 0    Апельсин
# 1        Киви
# 2    Мандарин
# 3      Яблоко
# Name: fruits, dtype: object

# %%
melb_data = pd.read_csv('data/melb_data.csv', sep=',')
display(melb_data.loc[15, 'Price'])
display(melb_data.loc[90, 'Date'])
display(round(melb_data.loc[3521, 'Landsize']/melb_data.loc[1690, 'Landsize']))
# Out:
# 1310000.0
# '10/09/2016'
# 3

# %%
display(melb_data.head())
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data.tail(7)
melb_data.shape
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
#            Distance  BuildingArea         Price
# count  13580.000000  13580.000000  1.358000e+04
# mean      10.137776    139.633972  1.075684e+06
# std        5.868725    392.217403  6.393107e+05
# min        0.000000      0.000000  8.500000e+04
# 25%        6.100000    122.000000  6.500000e+05
# 50%        9.200000    126.000000  9.030000e+05
# 75%       13.000000    129.940000  1.330000e+06
# max       48.100000  44515.000000  9.000000e+06

# %%
melb_data.describe(include=['object'])
# Out:
#            Suburb           Address   Type Method SellerG        Date  \
# count       13580             13580  13580  13580   13580       13580
# unique        314             13378      3      5     268          58
# top     Reservoir  36 Aberfeldie St      h      S  Nelson  27/05/2017
# freq          359                 3   9449   9022    1565         473
#
#        CouncilArea             Regionname         Coordinates
# count        12211                  13580               13580
# unique          33                      8               13097
# top       Moreland  Southern Metropolitan  -37.8361, 144.9966
# freq          1163                   4695                  12

# %%
melb_data['Regionname'].value_counts()
# Out:
# Regionname
# Southern Metropolitan         4695
# Northern Metropolitan         3890
# Western Metropolitan          2948
# Eastern Metropolitan          1471
# South-Eastern Metropolitan     450
# Eastern Victoria                53
# Northern Victoria               41
# Western Victoria                32
# Name: count, dtype: int64

# %%
melb_data['Regionname'].value_counts(normalize=True)
# Out:
# Regionname
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: proportion, dtype: float64

# %%
data = pd.DataFrame([[0,1], [1, 0], [1, 1]], columns=['А', 'B'])
print(data.shape)
# Out:
# (3, 2)

# %%
import collections as col

my_var=melb_data['CouncilArea'].isnull()
col.Counter(my_var)
# Out:
# Counter({False: 12211, True: 1369})

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
col.Counter(melb_data.dtypes)
# Out:
# Counter({dtype('O'): 9, dtype('int64'): 8, dtype('float64'): 6})

# %%
display(melb_data['Price'].mean()/melb_data['Price'].median())
display(melb_data['Distance'].mean())
display(melb_data['BuildingArea'].mean())
display(melb_data['Distance'].min())
# Out:
# 1.1912337535493698
# 10.13777614138439
# 139.63397229013256
# 0.0

# %%
display(col.Counter(melb_data['Regionname']))
display(col.Counter(melb_data['Coordinates']))
display(melb_data['Type'].value_counts(normalize=True))
# Out:
# Counter({'Southern Metropolitan': 4695,
#          'Northern Metropolitan': 3890,
#          'Western Metropolitan': 2948,
#          'Eastern Metropolitan': 1471,
#          'South-Eastern Metropolitan': 450,
#          'Eastern Victoria': 53,
#          'Northern Victoria': 41,
#          'Western Victoria': 32})
# Counter({'-37.8361, 144.9966': 12,
#          '-37.8035, 144.985': 8,
#          '-37.8424, 144.9449': 6,
#          '-37.8415, 144.9412': 5,
#          '-37.8127, 145.0094': 5,
#          '-37.8231, 144.9906': 5,
#          '-37.822, 145.0104': 5,
#          '-37.8607, 145.0116': 4,
#          '-37.8042, 144.9845': 4,
#          '-37.7846, 144.9785': 4,
#          '-37.7961, 144.9261': 4,
#          '-37.8095, 144.9691': 4,
#          '-37.8106, 144.9646': 4,
#          '-37.8413, 144.8741': 4,
#          '-37.8198, 145.005': 4,
#          '-37.859, 144.9767': 4,
#          '-37.8568, 144.9873': 4,
#          '-37.8424, 145.0184': 4,
# ...

# %%
print(melb_data['Price'].mean())
print(melb_data['Car'].max())
# Out:
# 1075684.079455081
# 10

# %%
rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))
# Out:
# Total income of real estate agencies: 1752934775.88

# %%
landsize_median = melb_data['Landsize'].median() 
landsize_mean =  melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 0.21205713983546193

# %%
print(melb_data['Rooms'].mode())
melb_data['Regionname'].mode()
# Out:
# 0    3
# Name: Rooms, dtype: int64
# 0    Southern Metropolitan
# Name: Regionname, dtype: object

# %%
melb_data['Distance'].std()
display(abs(melb_data['BuildingArea'].median()-melb_data['BuildingArea'].mean())/melb_data['BuildingArea'].median())
# Out:
# 0.10820612928676636

# %%
print(pd.DataFrame([1, 2, 4, 2, 3, 2, 1, 5, 6]).mode())
display(melb_data['Bedroom'].mode())
# Out:
#    0
# 0  2
# 0    3
# Name: Bedroom, dtype: int64

# %%
mask = melb_data['Price'] > 2000000
display(mask)
display(melb_data[mask].head())
melb_data[melb_data['Price'] > 2000000]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13575    False
# 13576    False
# 13577    False
# 13578     True
# 13579    False
# Name: Price, Length: 13580, dtype: bool
#     index       Suburb               Address  Rooms Type      Price Method  \
# 80     80  Albert Park  112 Beaconsfield Pde      3    h  2850000.0     PI
# 85     85  Albert Park     104 Richardson St      4    h  2300000.0      S
# 88     88  Albert Park        29 Faussett St      2    h  2120000.0      S
# 92     92  Albert Park           2 Dundas Pl      3    h  2615000.0      S
# 93     93  Albert Park          23 Finlay St      5    h  2100000.0      S
#
#      SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 80    Buxton   4/03/2017       3.3  ...    0     211.0         198.0
# 85  Marshall   7/05/2016       3.3  ...    1     153.0         180.0
# 88      Greg  10/09/2016       3.3  ...    1     199.0         107.0
# ...

# %%
melb_data[melb_data['Rooms'] == 3].shape[0]
# Out:
# 5881

# %%
melb_data[(melb_data['Rooms'] == 3) & (melb_data['Price'] < 300000)].shape
melb_data[((melb_data['Rooms'] == 3) | (melb_data['BuildingArea'] > 100)) & (melb_data['Price'] < 300000)].shape[0]
melb_data[melb_data['Type'] == 't']['Rooms'].max()
# Out:
# 5

# %%
mean_price = melb_data['Price'].mean()
melb_data[melb_data['Price'] > mean_price]['BuildingArea'].median()
# Out:
# 126.0

# %%
melb_data[melb_data['Bathroom']==0].shape[0]
# Out:
# 34

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data[(melb_data['SellerG']=='Nelson') & (melb_data['Price']>3000000)].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea']==0]['Price'].min()
# Out:
# 412500.0

# %%
method = (melb_data['Price']<1000000) & ((melb_data['Rooms']>5) | (melb_data['YearBuilt']>2015))
melb_data[method]['Price'].mean()
# Out:
# 769238.6363636364

# %%
method = (melb_data['Price']<3000000) & (melb_data['Type']=='h') 
melb_data[method]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object
