# %% [markdown]
# # <center> Визуализация данных: plotly

# %% [markdown]
# Спикер: Андрей Рысистов
#
# Контакты:
# * Телеграм @Rysistov
# * Slack @Андрей Рысистов (эксперт)

# %% [markdown]
# ## <center> 0. План занятия:
#     1. Обсудим что такое визуализация
#     2. Поговорим о библиотеке для интерактивной визуализации plotly
#     3. Разберем основные методы визуализации в plotly.express
#     4. Разберем основные методы визуализации в plotly.graph_objects

# %% [markdown]
# ## <center> 1. Визуализация: для чего нужна?

# %% [markdown]
# Лучший способ отобразить информацию и донести её до других — использовать визуальные методы: графики, диаграммы, тепловые карты и другие приёмы визуализации данных.
# Визуализация данных – это представление данных в виде, который обеспечивает наиболее эффективную работу человека по их изучению.
#
# Очень важный инструмент в рамках EDA, который облегчает определение распределений, поиск аномалий, зависимостей, первичное выдвижение гипотез и пр.
# Важность визуализации может продемонстрировать [квартет Энскомба](https://en.wikipedia.org/wiki/Anscombe%27s_quartet).

# %% [markdown]
# Классический пример:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/zp_predictions.jpg>

# %% [markdown]
# ##  <center> 2. Библиотека для интерактивной визуализации plotly

# %% [markdown]
# Библиотека Plotly является сравнительно новым коммерческим продуктом с бесплатной версией, который создавался специально для Data Science, в отличие от относительно старой библиотеки Matplotlib, которая изначально разрабатывалась для научных вычислений.
#
# → Библиотека Plotly позволяет строить интерактивные графики, которые можно приближать, отдалять, а также просматривать значения на графике в реальном времени. К тому же в библиотеке собрано огромнейшее количество красочных методов визуализации. У Plotly приятный дизайн, а способов работы с ней несколько.
#
# → С помощью Plotly можно делать сложные визуализации с элементами управления, например строить интерактивную 3D-визуализацию, карту мира и многое другое.

# %% [markdown]
# Раньше, дата-сайентисты использовали Plotly как «тяжёлую артиллерию» по визуализации данных для задач, в которых нужны крайне специфичные графики, которых нет в традиционных библиотеках (например, тепловой карты мира), или в задачах составления красивых дашбордов.
#
# Это было связано с тем, что традиционный Plotly имеет огромную функциональность со множеством параметров, в которых легко запутаться. Графики в библиотеке строятся иногда десятками строк кода, отрисовываются медленно и очень сильно нагружают видеокарту.

# %% [markdown]
# Сейчас, с появлением новых оптимизированных модулей и надстроек в Plotly (express и cufflinks), которые позволили упростить работу с библиотекой, в отрасли наблюдается тенденция постепенного перехода бизнеса к использованию Plotly при работе с данными, ведь бесплатную версию библиотеки разрешено применять в коммерческих продуктах.

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\ds\lessons\.venv\lib\site-packages (5.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\ds\lessons\.venv\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: six in c:\ds\lessons\.venv\lib\site-packages (from plotly) (1.16.0)

# %%
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## <center> 3. Знакомство с данными: видеоигры

# %% [markdown]
# Поработаем с данными о продажах и оценках видео-игр с [Kaggle Datasets](https://www.kaggle.com/ashaheedq/video-games-sales-2019?select=vgsales-12-4-2019.csv).

# %%
games_df = pd.read_csv('https://raw.githubusercontent.com/obulygin/SkillFactory/main/vgsales.csv')
games_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
games_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
games_df.shape
# Out:
# (16719, 16)

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
games_df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# Немного предобработаем данные:

# %%
data = games_df.copy()
data = data[data['Year_of_Release'].notna()]
data['User_Score'] = data.User_Score.replace('tbd', np.NaN).astype('float64')
#data['Critic_Score'] = data.Critic_Score.replace('tbd', np.NaN).astype('float64')

data['User_Count'] = data.User_Count.replace('<NA>', np.NaN).astype('float64')
data['Critic_Count'] = data.Critic_Count.replace('<NA>', np.NaN).astype('float64')

data['Year_of_Release'] = data.Year_of_Release.astype('Int64')

data['User_Score'] = data.User_Score * 10
#data = data.drop(['User_Count','Critic_Count'], axis=1)
data = data.sort_values('Year_of_Release', ascending=True, ignore_index=True)
data.tail()
# Out:
#                                                    Name Platform  \
# 16445                           Rise of the Tomb Raider      PS4
# 16446  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16447  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16448                  Brothers Conflict: Precious Baby      PSV
# 16449                            Imagine: Makeup Artist       DS
#
#        Year_of_Release         Genre     Publisher  NA_Sales  EU_Sales  \
# 16445             2016     Adventure   Square Enix      0.23      0.53
# 16446             2017  Role-Playing          Sega      0.00      0.00
# 16447             2017  Role-Playing          Sega      0.00      0.00
# 16448             2017        Action  Idea Factory      0.00      0.00
# 16449             2020    Simulation       Ubisoft      0.27      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 16445      0.04         0.14          0.94           NaN           NaN
# 16446      0.01         0.00          0.01           NaN           NaN
# 16447      0.04         0.00          0.04           NaN           NaN
# 16448      0.01         0.00          0.01           NaN           NaN
# 16449      0.00         0.02          0.29           NaN           NaN
#
#        User_Score  User_Count Developer Rating
# 16445         NaN         NaN       NaN    NaN
# 16446         NaN         NaN       NaN    NaN
# 16447         NaN         NaN       NaN    NaN
# 16448         NaN         NaN       NaN    NaN
# 16449         NaN         NaN   Ubisoft      E

# %% [markdown]
# # <center> 4. Plotly express

# %% [markdown]
# Plotly позволяет строить графики в нескольких режимах. Рассмотрим самый новый и подающий надежды — экспресс-режим. Его функциональность скромнее, чем у полного режима Plotly, но нам её будет более чем достаточно. Для работы в экспресс-режиме предназначен модуль plotly.express. Он был выпущен в марте 2019 года и находится в процессе активной разработки.

# %% [markdown]
# Основные функции:
#
# * line() — линейные графики;
# * histogram() — гистограммы;
# * scatter() — диаграммы рассеяния;
# * box() — коробчатые диаграммы;
# *  bar() — столбчатые диаграммы;
# * pie() — круговые диаграммы.

# %% [markdown]
# Рассмотрим основные возможности:

# %%
data.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release       0
# Genre                 2
# Publisher            32
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8467
# Critic_Count       8467
# User_Score         8987
# User_Count         8987
# Developer          6543
# Rating             6681
# dtype: int64

# %%
cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cols
#
# NameError: name 'cols' is not defined

# %%
null_data = data.isnull().sum()
cols = null_data[null_data > 0].index

fig = px.imshow(
    data[cols].isnull().astype('int'),
    labels={'x': 'Columns', 'y': 'Rows sorted by year'},
    title='Heatmap of NaN'
)
fig.show()
# Out:
# c:\DS\lessons\.venv\Lib\site-packages\plotly\express\_imshow.py:349: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if img.dtype == np.bool:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       1 null_data = data.isnull().sum()
#       2 cols = null_data[null_data > 0].index
# ----> 4 fig = px.imshow(
#       5     data[cols].isnull().astype('int'),
#       6     labels={'x': 'Columns', 'y': 'Rows sorted by year'},
#       7     title='Heatmap of NaN'
#       8 )
#       9 fig.show()
#
# File c:\DS\lessons\.venv\Lib\site-packages\plotly\express\_imshow.py:349, in imshow(img, zmin, zmax, origin, labels, x, y, animation_frame, facet_col, facet_col_wrap, facet_col_spacing, facet_row_spacing, color_continuous_scale, color_continuous_midpoint, range_color, title, template, width, height, aspect, contrast_rescaling, binary_string, binary_backend, binary_compression_level, binary_format)
#     346     binary_string = img.ndim >= (3 + slice_dimensions) and not is_dataframe
#     348 # Cast bools to uint8 (also one byte)
# --> 349 if img.dtype == np.bool:
#     350     img = 255 * img.astype(np.uint8)
#     352 if range_color is not None:
#
# File c:\DS\lessons\.venv\Lib\site-packages\numpy\__init__.py:338, in __getattr__(attr)
#     333     warnings.warn(
#     334         f"In the future `np.{attr}` will be defined as the "
#     335         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     337 if attr in __former_attrs__:
# --> 338     raise AttributeError(__former_attrs__[attr])
#     340 if attr == 'testing':
#     341     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
data = data.fillna({
    'Genre': data['Genre'].mode()[0],
    'Publisher': data['Publisher'].mode()[0]
})
data = data.dropna(subset=['Name'])

# %%
fig = px.histogram(
    data_frame=data,
    x='Critic_Score',
    nbins=25,
    title='Distribution of critic score',
    width=700,
    height=500,
    marginal='box',
    #histnorm='percent'
)
fig.show()

# %%
fig = px.box(
    data_frame=data,
    x='Critic_Score',
    title='Boxplot of critic score',
    width=700,
    height=500,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="3954a74b-add4-435b-871e-8b927f9fc5a9" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3954a74b-add4-435b-871e-8b927f9fc5a9")) {                    Plotly.newPlot(                        "3954a74b-add4-435b-871e-8b927f9fc5a9",                        [{"alignmentgroup":"True","hovertemplate":"Critic_Score=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"type":"box","x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,59.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,64.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,85.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,69.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %%
fig = px.histogram(
    data,
    x='User_Count',
    y='Genre',
    color='Genre',
    title='Distribution of user count by genre',
    width=700,
    height=500,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="cbac6a6d-4c53-49fc-8e90-4d6c85e0638a" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbac6a6d-4c53-49fc-8e90-4d6c85e0638a")) {                    Plotly.newPlot(                        "cbac6a6d-4c53-49fc-8e90-4d6c85e0638a",                        [{"alignmentgroup":"True","bingroup":"y","histfunc":"sum","hovertemplate":"Genre=%{y}<br>sum of User_Count=%{x}<extra></extra>","legendgroup":"Shooter","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Shooter","offsetgroup":"Shooter","orientation":"h","showlegend":true,"type":"histogram","x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,1796.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,4.0,null,null,null,null,null,null,3161.0,null,null,6.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,80.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,10.0,null,null,40.0,null,null,13.0,4.0,null,7.0,5.0,20.0,null,null,null,20.0,15.0,12.0,44.0,86.0,8.0,4.0,11.0,36.0,69.0,49.0,31.0,20.0,15.0,17.0,61.0,null,13.0,null,5.0,null,1283.0,5.0,1016.0,94.0,6.0,null,7.0,null,4.0,null,16.0,11.0,5.0,11.0,48.0,9.0,null,28.0,null,null,16.0,16.0,25.0,8.0,65.0,10.0,21.0,null,7.0,5.0,6.0,9.0,19.0,135.0,null,9.0,null,4.0,8.0,4.0,null,98.0,null,4.0,null,null,9.0,747.0,26.0,null,16.0,82.0,8.0,null,null,66.0,7.0,null,null,16.0,127.0,4.0,null,null,25.0,327.0,27.0,7.0,10.0,36.0,46.0,null,33.0,
,40.0,68.0,12.0,92.0,null,58.0,86.0,53.0,63.0,59.0,null,70.0,72.0,null,52.0,73.0,80.0,61.0,null,74.0,75.0,74.0,null,85.0,null,64.0,85.0,78.0,46.0,82.0,73.0,71.0,90.0,73.0,83.0,83.0,73.0,60.0,80.0,84.0,80.0,49.0,73.0,81.0,83.0,80.0,69.0,69.0,62.0,79.0,74.0,68.0,65.0,91.0,null,90.0,90.0,84.0,89.0,89.0,69.0,80.0,74.0,null,89.0,54.0,null,79.0,63.0, ...

# %%
fig = px.histogram(
    data,
    x='User_Score',
    #y='Genre',
    #color='Genre',
    title='Distribution of user score by genre',
    width=700,
    height=400,
    #points="all"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="ca6b257f-b33a-468d-8dba-570f42370398" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca6b257f-b33a-468d-8dba-570f42370398")) {                    Plotly.newPlot(                        "ca6b257f-b33a-468d-8dba-570f42370398",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"User_Score=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,58.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,22.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,82.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,63.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %%
fig = px.box(
    data,
    x='User_Score',
    #y='Genre',
    #color='Genre',
    title='Distribution of user score by genre',
    width=700,
    height=400,
    #points="all"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="a8cfa71e-1597-4e87-bdf7-6b0a999f72d2" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8cfa71e-1597-4e87-bdf7-6b0a999f72d2")) {                    Plotly.newPlot(                        "a8cfa71e-1597-4e87-bdf7-6b0a999f72d2",                        [{"alignmentgroup":"True","hovertemplate":"User_Score=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"type":"box","x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,58.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,22.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,82.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,63.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %%
fig = px.violin(
    data,
    x='User_Score',
    #y='Genre',
    #color='Genre',
    title='Distribution of user score by genre',
    width=700,
    height=400,
    #points="all"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="a7d9c51c-053c-47d3-9798-426f6aa87d46" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7d9c51c-053c-47d3-9798-426f6aa87d46")) {                    Plotly.newPlot(                        "a7d9c51c-053c-47d3-9798-426f6aa87d46",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"User_Score=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"h","scalegroup":"True","showlegend":false,"type":"violin","x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,58.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,22.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,82.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,63.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
line_data = data.groupby('Year_of_Release', as_index=False)['Global_Sales'].sum()
fig = px.line(
    line_data,
    x='Year_of_Release',
    y='Global_Sales',
    title='Dynamics of video game sales',
    width=800,
    height=300
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="4e701f21-4e4a-47e3-b911-de0d8245517a" class="plotly-graph-div" style="height:300px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e701f21-4e4a-47e3-b911-de0d8245517a")) {                    Plotly.newPlot(                        "4e701f21-4e4a-47e3-b911-de0d8245517a",                        [{"hovertemplate":"Year_of_Release=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"xaxis":"x","y":[11.379999999999999,35.769999999999996,28.86,16.79,50.36,53.940000000000005,37.07,21.74,47.22,73.45,49.39,32.23,76.17,45.980000000000004,79.18,88.11,199.15,200.98,256.45,251.25,201.58,331.47,395.51,357.8,419.05,458.31,518.22,605.37,671.79,658.88,590.59,507.79,355.84,361.24,331.51,268.05,130.1,0.060000000000000005,0.29],"yaxis":"y"}],                        {"height":300,"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"# ...

# %%
fig = px.pie(
    data_frame=data,
    names='Genre',
    height=500,
    width=700,
    title='Ratio of genres',
    #hole=0.2
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="fa460a86-dd03-4703-8621-5c0759619a12" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa460a86-dd03-4703-8621-5c0759619a12")) {                    Plotly.newPlot(                        "fa460a86-dd03-4703-8621-5c0759619a12",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Genre=%{label}<extra></extra>","labels":["Shooter","Action","Shooter","Fighting","Sports","Misc","Misc","Misc","Misc","Racing","Action","Platform","Sports","Action","Action","Puzzle","Shooter","Action","Action","Action","Action","Shooter","Action","Sports","Action","Shooter","Platform","Action","Action","Platform","Shooter","Action","Simulation","Action","Shooter","Puzzle","Action","Action","Shooter","Action","Sports","Action","Action","Action","Sports","Action","Action","Action","Action","Shooter","Shooter","Action","Shooter","Action","Shooter","Action","Action","Platform","Puzzle","Action","Racing","Action","Action","Action","Puzzle","Action","Action","Action","Action","Platform","Shooter","Platform","Shooter","Action","Misc","Racing","Action","Action","Sports","Action","Action","Action","Action","Shooter","Shooter","Action","Platform","Platform","Puzzle","Sports","Shooter","Puzzle","Shooter","Misc","Action","Platform","Action","Action","Action","Sports","Action","Action","Action","Platform","Platform","Platform","Platform","Adventure","Puzzle","Platform","Sports","Sports","Shooter","Puzzle","Shooter","Racing","Puzzle","Racing","Racing","Action","Shooter","Misc","Action","Puzzle","Platform","Sports","Platform","Puzzle","Platform","Puzzle","Shooter","Puzzle","Action","Fighting","Simulation","Platform","Role-Playing","Action","Action","Racing","Shooter","Action","Action","Shooter","Shooter","Action","Platform","Sports","Platform","Platform","Shooter","Sports","Platform","Platform","Platform","Action","Sports","Sports","Action","Fighting","Role-Playing","Sports","Role-Playing","Platform","Action","Fighting","Sports","Role-Playing","Platform","Shooter","Adventure","Shooter","Sports","Role-Playing","Platform","Sports","Action","Simulation","Sports","Racing","Puzzle","Role-Playing","Shooter","Platform","Role-Playing","Action","Platform","Platform","Role-Playing","Puzzle","Puzzle","Puzzle","Platform","Platform","Shooter","Role-Playing","Puzzle","Platform","Action","Sports","Misc","Sports","Action","Puzzle","Sports","Racing","Simulation","Sports","Role-Playing","Sports","Platform","Puzzle","Racing","Action","Puzzle","Platform","Action","Platform","Sports","Action","Role-Playing","Strategy","Platform","Misc","Puzzle","Adventure","Sports","Role-Playing","Racing","Puzzle","Adventure","Platform","Role-Playing","Simulation","Sports","Action","Role-Playing","Platform","Role-Playing","Sports","Sports","Platform","Shooter","Sports","Puzzle","Platform","Platform","Shooter","Action","Strategy","Strategy","Action","Shooter","Sports","Puzzle","Role-Playing","Simulation","Action","Strategy","Sports","Action","Fighting","Sports","Adventure","Sports","Sports","Fighting","Fighting","Misc","Role-Playing","Puzzle","Simulation","Platform","Role-Playing","Action","Platform","Fighting","Racing","Strategy","Puzzle","Platform","Puzzle","Adventure","Platform","Role-Playing","Role-Playing","Platform","Platform","Shooter","Shooter","Racing","Strategy","Adventure","Sports","Puzzle","Shooter","Strategy","Fighting","Fighting","Misc","Fighting","Puzzle","Role-Playing","Adventure","Fighting","Action","Platform","Platform","Fighting","Racing","Platform","Platform","Fighting","Strategy","Role-Playing","Shooter","Sports","Role-Playing","Action","Platform","Fighting","Puzzle","Sports","Fighting","Racing","Sports","Misc","Role-Playing","Sports","Adventure","Sports","Role-Pla ...

# %%
bar_data = data.groupby('Genre')['Global_Sales'].sum().reset_index()#.rename(columns={'index':'Genre', 'Genre': 'Count'})
bar_data.head()
# Out:
#        Genre  Global_Sales
# 0     Action       1717.63
# 1  Adventure        233.46
# 2   Fighting        442.63
# 3       Misc        790.94
# 4   Platform        825.86

# %%
fig = px.bar(
    data_frame=bar_data,
    x='Genre',
    y='Global_Sales',
    color='Genre',
    height=500,
    width=700,
    title='Ratio of genres',
    #hole=0.2
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="ed6993fe-fcf0-4067-8930-8492014b1a87" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed6993fe-fcf0-4067-8930-8492014b1a87")) {                    Plotly.newPlot(                        "ed6993fe-fcf0-4067-8930-8492014b1a87",                        [{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Action","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Action","offsetgroup":"Action","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Action"],"xaxis":"x","y":[1717.63],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Adventure","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Adventure","offsetgroup":"Adventure","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Adventure"],"xaxis":"x","y":[233.46],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Fighting","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fighting","offsetgroup":"Fighting","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Fighting"],"xaxis":"x","y":[442.63],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Misc","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Misc","offsetgroup":"Misc","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Misc"],"xaxis":"x","y":[790.94],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Platform","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Platform","offsetgroup":"Platform","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Platform"],"xaxis":"x","y":[825.86],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Puzzle","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Puzzle","offsetgroup":"Puzzle","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Puzzle"],"xaxis":"x","y":[240.33],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Racing","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Racing","offsetgroup":"Racing","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Racing"],"xaxis":"x","y":[723.7],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Role-Playing","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Role-Playing","offsetgroup":"Role-Playing","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Role-Playing"],"xaxis":"x","y":[930.9],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Shooter","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Shooter","offsetgroup":"Shooter","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Shooter"],"xaxis":"x","y":[1041.83],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Simulation","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Simulation","offsetgroup":"Simulation","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Simulation"],"xaxis":"x","y":[388.4],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Genre=%{x}<br>Global_Sales=%{y}<extra></extra>","legendgroup":"Spor ...

# %%
top_data = data.groupby(['Platform', 'Year_of_Release'], as_index=False)['Global_Sales'].sum()
top_data.columns = ['Platform', 'Year_of_Release', 'Sum']
top_data = top_data[top_data['Year_of_Release'] > 2000]
top_data['Year_of_Release'] = top_data['Year_of_Release'].astype('object')

fig = px.bar(
    data_frame=top_data,
    x='Year_of_Release',
    y='Sum',
    color='Platform',
    barmode="group",
    title="Total released video-games by platform"
)
#fig.update_layout(width=1000, title='New title')
fig.update_xaxes(type='category', categoryorder='category ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="66d79566-574c-4626-bb8c-b300a745502d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66d79566-574c-4626-bb8c-b300a745502d")) {                    Plotly.newPlot(                        "66d79566-574c-4626-bb8c-b300a745502d",                        [{"alignmentgroup":"True","hovertemplate":"Platform=3DS<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"3DS","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"3DS","offsetgroup":"3DS","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[63.17,51.36,56.64,43.8,27.81,15.139999999999999],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=DC<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"DC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"DC","offsetgroup":"DC","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001,2002,2007,2008],"xaxis":"x","y":[1.07,0.29,0.02,0.04],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=DS<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"DS","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"DS","offsetgroup":"DS","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2020],"xaxis":"x","y":[17.270000000000003,130.22,119.92,147.26,145.45,119.46,84.98,26.26,11.06,1.54,0.29],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=GB<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"GB","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"GB","offsetgroup":"GB","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001],"xaxis":"x","y":[9.24],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=GBA<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"GBA","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"GBA","offsetgroup":"GBA","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[61.62,74.38,56.73,78.09,33.9,5.35,3.43],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=GC<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"GC","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"GC","offsetgroup":"GC","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001,2002,2003,2004,2005,2006,2007],"xaxis":"x","y":[26.3,51.93,50.660000000000004,28.89,27.8,11.290000000000001,0.27],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=N64<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"N64","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"N64","offsetgroup":"N64","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001,2002],"xaxis":"x","y":[3.26,0.08],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=PC<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"PC","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"PC","offsetgroup":"PC","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":[2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[5.51,8.59,8.91,10.41,4.41,2.91,9.33,12.59,16.94,24.36,35.1,23.28,12.4,13.3,8.55,5.2700000000000005],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"Platform=PS<br>Year_of_Release=%{x}<br>Sum=%{y}<extra></extra>","legendgroup":"PS","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"PS","offsetgroup":"PS","orientation":"v","showlegend":true,"textposition":"auto","type":"b ...

# %% [markdown]
# # <center> 5. Plotly Objects

# %% [markdown]
# Часто возникает потребность более гибкого управления настройками графика и построения более сложных визуализаций. В таком случае можно использовать классические графические объекты из библиотеки plotly. Они находятся в модуле graph_objects

# %%
import plotly.graph_objects as go

# %%
#предварительно подготовим данные для круговой диаграммы
#сгруппируем наши данные по признаку жанра и вычисляем суммарные мировые продажи каждого жанра
#результат отсортируем по убыванию продаж
pie_data = data.groupby(
    'Genre', as_index=False
)['Global_Sales'].sum().sort_values('Global_Sales', ascending=False)

#создаем фигуру
fig = go.Figure()
#добавляем пространство для графика
#в пространстве вызываем функцию go.Pie для построения круговой диаграммы
#передаем необходимые параметры
fig.add_trace(trace=go.Pie(
    labels=pie_data['Genre'],
    values=pie_data['Global_Sales'],
    pull=[0.09, 0.07, 0.05, 0.03, 0, 0, 0, 0, 0],
    hole=0.1
))
#обновляем параметры пространства: позицию текста, вид справочной информации
fig.update_traces(textposition='inside', textinfo='percent+label')
#обновляем параметры фона: задаем название графику, ширину и высоту
fig.update_layout(title="Percent of sales by Genre", height=500, width=700)
#отображаем фигуру и построенный на ней график
fig.show()

# %%
#построим пузырьковую диаграмму, отображающую зависимость оценки критиков от оценки пользователей
#размер точки будет зависеть от объема мировых продаж
s = data['Global_Sales']
#нормируем размер точек на диапазон от 0 до 1
sizes = (s -  s.min())/(s.max() - s.min()) * 100
#создаем фигуру
fig = go.Figure()
#добавляем пространство для графика
#на пространстве строим диаграмму рассеяния
fig.add_trace(trace=go.Scatter(
    x=data['User_Score'],
    y=data['Critic_Score'],
    mode='markers', #задаем маркеры
    marker={'size': sizes} #и их размеры
))
#добавляем на диагональную пространство линию
fig.add_trace(go.Scatter(
    x=[0, 100],
    y=[0, 100],
    mode='lines'
))
#обновляем параметры фона: задаем название графика, его ширину и высоту
fig.update_layout(title="Dependence of critic score on user score", height=500, width=700)
#отображаем фигуру и построенный на ней график
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="4f5c595a-1c8b-4fd5-a398-659ab45d3654" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f5c595a-1c8b-4fd5-a398-659ab45d3654")) {                    Plotly.newPlot(                        "4f5c595a-1c8b-4fd5-a398-659ab45d3654",                        [{"marker":{"size":[5.2108579738245275,0.3999030538051382,3.3325254483761517,0.9209888511875909,0.5816771691711101,0.31507513330101794,1.3814832767813863,0.27872031022782356,1.2603005332040718,0.5695588948133785,0.3393116820164808,5.441105186621425,0.21812893843916625,0.19389238972370335,0.9209888511875909,0.7028599127484246,1.6359670382937472,0.4362578768783325,0.7028599127484246,0.945225399903054,0.46049442559379544,0.27872031022782356,0.27872031022782356,0.14541929229277753,0.5089675230247213,1.2603005332040718,1.7571497818
NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0             1980     10.59      0.67       0.0         0.12         11.38
# 1             1981     33.40      1.96       0.0         0.32         35.77
# 2             1982     26.92      1.65       0.0         0.31         28.86

# %%
#создаем фигуру
fig = go.Figure()
#выделим список целевых регионов
regions = ['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
#создаем цикл по выделенным регионам
for region in regions:
    #на каждой итерации добавляем на фигуру новый график, соответствующий продажам текущего региона
    fig.add_trace(go.Scatter(
        x=geo_data['Year_of_Release'],
        y=geo_data[region],
        mode='lines', #линейный график
        stackgroup='one', #заливка площади под графиком
        name=region, #имя графика соответствует региону
    ))
#обновляем параметры фона: задаем название графика
fig.update_layout(title="Total sales per year by region (Millions)")
#обновляем параметры оси x: задаем поворот меток на оси x
fig.update_xaxes(tickangle=45)
#отображаем график
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="48f16581-1bd5-4ba4-8f2d-2d7c126d8eea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48f16581-1bd5-4ba4-8f2d-2d7c126d8eea")) {                    Plotly.newPlot(                        "48f16581-1bd5-4ba4-8f2d-2d7c126d8eea",                        [{"mode":"lines","name":"NA_Sales","stackgroup":"one","type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"y":[10.59,33.4,26.92,7.76,33.28,33.73,12.5,8.459999999999999,23.869999999999997,45.15,25.46,12.76,33.89,15.12,28.16,24.83,86.76,94.75,128.36,126.06,94.5,173.98,216.19,193.61,222.51,242.15,262.13,309.89,348.69,335.55,300.65,238.79,153.26,153.65,132.27,106.86,44.93,0.0,0.27]},{"mode":"lines","name":"EU_Sales","stackgroup":"one","type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"y":[0.67,1.96,1.65,0.8,2.1,4.74,2.84,1.41,6.59,8.44,7.63,3.95,11.71,4.65,14.879999999999999,14.9,47.26,48.32,66.9,62.67,52.77,94.89,109.75,103.81,107.28,121.11,127.89,157.82,181.14000000000001,187.94,171.42,162.97,114.59,121.55,122.74,96.72,51.22,0.0,0.0]},{"mode":"lines","name":"JP_Sales","stackgroup":"one","type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"y":[0.0,0.0,0.0,8.1,14.27,14.56,19.81,11.629999999999999,15.76,18.36,14.879999999999999,14.780000000000001,28.91,25.330000000000002,33.99,45.75,57.44,48.87,50.04,52.34,42.77,39.86,41.76,34.2,41.65,54.27,73.74,60.29,60.25,61.89,59.49,53.07,51.8,47.69,39.69,34.09,19.31,0.060000000000000005,0.0]},{"mode":"lines","name":"Other_Sales","stackgroup":"one","type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"y":[0.12,0.32,0.31,0.14,0.7,0.92,1.93,0.2,0.99,1.5,1.4000000000000001,0.74,1.65,0.89,2.2,2.64,7.6899999999999995,9.13,11.01,10.040000000000001,11.620000000000001,22.73,27.27,25.92,47.24,40.29,53.95,76.75,81.42,73.44,58.57,52.75,36.19,38.35,36.83,30.31,14.48,0.0,0.02]},{"mode":"lines","name":"Global_Sales","stackgroup":"one","type":"scatter","x":[1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2020],"y":[11.379999999999999,35.769999999999996,28.86,16.79,50.36,53.940000000000005,37.07,21.74,47.22,73.45,49.39,32.23,76.17,45.980000000000004,79.18,88.11,199.15,200.98,256.45,251.25,201.58,331.47,395.51,357.8,419.05,458.31,518.22,605.37,671.79,658.88,590.59,507.79,355.84,361.24,331.51,268.05,130.1,0.060000000000000005,0.29]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"cho ...

# %%
#выделим топ 5 издательств на каждом из региональных рынков
#для этого сгруппируем данные по признаку Publisher и посчитаем суммарные продажи в каждом регионе
#отсортируем данные по убыванию и возьмем первые 5 элементов
EU = data.groupby('Publisher', as_index=False)['EU_Sales'].sum()
EU = EU.sort_values(by='EU_Sales', ascending=False).iloc[:5]
EU_publishers = EU['Publisher']

JP =  data.groupby('Publisher', as_index=False)['JP_Sales'].sum()
JP = JP.sort_values(by='JP_Sales', ascending=False).iloc[:5]
JP_publishers = JP['Publisher']

NA = data.groupby('Publisher', as_index=False)['NA_Sales'].sum()
NA = NA.sort_values(by='NA_Sales', ascending=False).iloc[:5]
NA_publishers = NA['Publisher']

Other = data.groupby('Publisher', as_index=False)['Other_Sales'].sum()
Other = Other.sort_values(by='Other_Sales', ascending=False).iloc[0:5]
Other_publishers = Other['Publisher']

Global = data.groupby('Publisher', as_index=False)['Global_Sales'].sum()
Global = Global.sort_values(by='Global_Sales', ascending=False).iloc[0:5]
Global_publishers = Global['Publisher']

# %%
#создаем фигуру
fig = go.Figure()

fig.add_trace(
    go.Bar(y=NA['NA_Sales'],
           x=NA['Publisher'],
           name="North America",
           marker={'color': NA['NA_Sales'],'colorscale': 'tealgrn'}
          )
    )
fig.add_trace(
    go.Bar(y=EU['EU_Sales'],
           x=EU_publishers,
           name="Europe",
           marker={'color': EU['EU_Sales'],'colorscale': 'tealgrn'},
           visible=False
           )
    )
fig.add_trace(
    go.Bar(y=JP['JP_Sales'],
           x=JP_publishers,
           name="Japan",
           marker={'color': JP['JP_Sales'],'colorscale': 'tealgrn'},
           visible=False
           )
    )

fig.add_trace(
    go.Bar(y=Other['Other_Sales'],
           x=Other_publishers,
           name="Others",
           marker={'color': Other['Other_Sales'],'colorscale': 'tealgrn'},
           visible=False
           )
    )

fig.add_trace(
    go.Bar(y=Global['Global_Sales'],
           x=Global_publishers,
           name="Global",
           marker={'color': Global['Global_Sales'],'colorscale': 'tealgrn'},
               visible=False
           )
    )

buttons = []
countries = ['North America', 'Europe', 'Japan', 'Others', 'Global']
for i, country in enumerate(countries):
    buttons.append(dict(
        label=country,
        method="update",
        args=[{"visible": [False] * i + [True] + [False] * (3-i+1)},
              {"title": f"Top 5 Publishers for {country}"}]
    ))

fig.update_layout(
    title_text="Top 5 Publishers per region",
    xaxis_domain=[0.05, 1.0],
    updatemenus=[
        dict(
            type="buttons",
            direction="right",
            #active=0,
            x=0.57,
            y=1.2,
            buttons=buttons,
        )
    ])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="6daec79e-39a5-40b7-bf02-0e1f27b7f48d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6daec79e-39a5-40b7-bf02-0e1f27b7f48d")) {                    Plotly.newPlot(                        "6daec79e-39a5-40b7-bf02-0e1f27b7f48d",                        [{"marker":{"color":[815.86,594.4,428.92,266.17,252.12],"colorscale":[[0.0,"rgb(176, 242, 188)"],[0.16666666666666666,"rgb(137, 232, 172)"],[0.3333333333333333,"rgb(103, 219, 165)"],[0.5,"rgb(76, 200, 163)"],[0.6666666666666666,"rgb(56, 178, 163)"],[0.8333333333333334,"rgb(44, 152, 160)"],[1.0,"rgb(37, 125, 152)"]]},"name":"North America","type":"bar","x":["Nintendo","Electronic Arts","Activision","Sony Computer Entertainment","Ubisoft"],"y":[815.86,594.4,428.92,266.17,252.12]},{"marker":{"color":[418.58,372.41,214.1,186.4,161.72],"colorscale":[[0.0,"rgb(176, 242, 188)"],[0.16666666666666666,"rgb(137, 232, 172)"],[0.3333333333333333,"rgb(103, 219, 165)"],[0.5,"rgb(76, 200, 163)"],[0.6666666666666666,"rgb(56, 178, 163)"],[0.8333333333333334,"rgb(44, 152, 160)"],[1.0,"rgb(37, 125, 152)"]]},"name":"Europe","type":"bar","visible":false,"x":["Nintendo","Electronic Arts","Activision","Sony Computer Entertainment","Ubisoft"],"y":[418.58,372.41,214.1,186.4,161.72]},{"marker":{"color":[457.74,127.62,91.03,74.15,67.73],"colorscale":[[0.0,"rgb(176, 242, 188)"],[0.16666666666666666,"rgb(137, 232, 172)"],[0.3333333333333333,"rgb(103, 219, 165)"],[0.5,"rgb(76, 200, 163)"],[0.6666666666666666,"rgb(56, 178, 163)"],[0.8333333333333334,"rgb(44, 152, 160)"],[1.0,"rgb(37, 125, 152)"]]},"name":"Japan","type":"bar","visible":false,"x":["Nintendo","Namco Bandai Games","Konami Digital Entertainment","Sony Computer Entertainment","Capcom"],"y":[457.74,127.62,91.03,74.15,67.73]},{"marker":{"color":[126.92,94.55,79.62,75.27,55.68],"colorscale":[[0.0,"rgb(176, 242, 188)"],[0.16666666666666666,"rgb(137, 232, 172)"],[0.3333333333333333,"rgb(103, 219, 165)"],[0.5,"rgb(76, 200, 163)"],[0.6666666666666666,"rgb(56, 178, 163)"],[0.8333333333333334,"rgb(44, 152, 160)"],[1.0,"rgb(37, 125, 152)"]]},"name":"Others","type":"bar","visible":false,"x":["Electronic Arts","Nintendo","Sony Computer Entertainment","Activision","Take-Two Interactive"],"y":[126.92,94.55,79.62,75.27,55.68]},{"marker":{"color":[1786.72,1108.37,725.14,606.27,470.45],"colorscale":[[0.0,"rgb(176, 242, 188)"],[0.16666666666666666,"rgb(137, 232, 172)"],[0.3333333333333333,"rgb(103, 219, 165)"],[0.5,"rgb(76, 200, 163)"],[0.6666666666666666,"rgb(56, 178, 163)"],[0.8333333333333334,"rgb(44, 152, 160)"],[1.0,"rgb(37, 125, 152)"]]},"name":"Global","type":"bar","visible":false,"x":["Nintendo","Electronic Arts","Activision","Sony Computer Entertainment","Ubisoft"],"y":[1786.72,1108.37,725.14,606.27,470.45]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6 ...

# %% [markdown]
# ##  <center> 6. Дополнительные источники

# %% [markdown]
# ### Как правильно выбрать тип визуализации?
#
# [DataVizCatalogue](https://datavizcatalogue.com/)
# [ExtremePresentation](https://extremepresentation.com/tools/)
# [PythonGraphGallery](https://www.python-graph-gallery.com/)
# [А так не надо](https://t.me/awfulcharts)
#
# ### Документация plotly
#
# https://plotly.com/python/
#
# ### Обратная связь:
#
# https://skillfactoryschool.typeform.com/to/E9YAIWSL#course=xxxxx&webinar=xxxxx&link=xxxxx
